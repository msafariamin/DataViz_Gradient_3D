# %%
import matplotlib.pyplot as plt
from math import *
import numpy as np

# %%
from mpl_toolkits.mplot3d import Axes3D

def f(x, y):
    return np.exp(-(x*x + y*y))

x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
ax = plt.axes(projection='3d')

ax.plot_surface(X, Y, Z, rstride=1, cstride=1,cmap='viridis', edgecolor=None)

ax.set_title("Surface d'un gradient");

# %%
fig = plt.figure()
# ax = fig.add_subplot(111, projection='3d')
ax = plt.axes(projection='3d')

ax.plot_surface(X, Y, Z, rstride=1, cstride=1,cmap='viridis', edgecolor='black')

# %%
print(X,Y,Z)
# Out:
# [[-2.         -1.95959596 -1.91919192 ...  1.91919192  1.95959596
#    2.        ]
#  [-2.         -1.95959596 -1.91919192 ...  1.91919192  1.95959596
#    2.        ]
#  [-2.         -1.95959596 -1.91919192 ...  1.91919192  1.95959596
#    2.        ]
#  ...
#  [-2.         -1.95959596 -1.91919192 ...  1.91919192  1.95959596
#    2.        ]
#  [-2.         -1.95959596 -1.91919192 ...  1.91919192  1.95959596
#    2.        ]
#  [-2.         -1.95959596 -1.91919192 ...  1.91919192  1.95959596
#    2.        ]] [[-2.         -2.         -2.         ... -2.         -2.
#   -2.        ]
#  [-1.95959596 -1.95959596 -1.95959596 ... -1.95959596 -1.95959596
#   -1.95959596]
#  [-1.91919192 -1.91919192 -1.91919192 ... -1.91919192 -1.91919192
#   -1.91919192]
#  ...
#  [ 1.91919192  1.91919192  1.91919192 ...  1.91919192  1.91919192
#    1.91919192]
#  [ 1.95959596  1.95959596  1.95959596 ...  1.95959596  1.95959596
#    1.95959596]
#  [ 2.          2.          2.         ...  2.          2.
#    2.        ]] [[0.00033546 0.00039366 0.00046045 ... 0.00046045 0.00039366 0.00033546]
#  [0.00039366 0.00046196 0.00054034 ... 0.00054034 0.00046196 0.00039366]
#  [0.00046045 0.00054034 0.00063202 ... 0.00063202 0.00054034 0.00046045]
#  ...
#  [0.00046045 0.00054034 0.00063202 ... 0.00063202 0.00054034 0.00046045]
#  [0.00039366 0.00046196 0.00054034 ... 0.00054034 0.00046196 0.00039366]
#  [0.00033546 0.00039366 0.00046045 ... 0.00046045 0.00039366 0.00033546]]
